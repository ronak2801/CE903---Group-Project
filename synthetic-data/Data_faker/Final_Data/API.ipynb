# %%
import pandas as pd
import requests
import csv

# %%
df = pd.read_excel("nosh_product_data.xlsx")
df
# Out:
#      product_id          product  shelf_life usual_storage
# 0             1        spaghetti         NaN        pantry
# 1             2            onion        13.0        pantry
# 2             3            sugar         NaN        pantry
# 3             4          mustard        60.0        pantry
# 4             5     tomato sauce         NaN        pantry
# ..          ...              ...         ...           ...
# 205         206  cooked broccoli         7.0        fridge
# 206         207         mushroom         7.0        fridge
# 207         208  cooked mushroom         7.0        fridge
# 208         209  sliced mushroom         5.0        fridge
# 209         210   dried mushroom       730.0        fridge
#
# [210 rows x 4 columns]

# %%
dff = df.copy()
dff
# Out:
#      product_id          product  shelf_life usual_storage
# 0             1        spaghetti         NaN        pantry
# 1             2            onion        13.0        pantry
# 2             3            sugar         NaN        pantry
# 3             4          mustard        60.0        pantry
# 4             5     tomato sauce         NaN        pantry
# ..          ...              ...         ...           ...
# 205         206  cooked broccoli         7.0        fridge
# 206         207         mushroom         7.0        fridge
# 207         208  cooked mushroom         7.0        fridge
# 208         209  sliced mushroom         5.0        fridge
# 209         210   dried mushroom       730.0        fridge
#
# [210 rows x 4 columns]

# %%
items = ["product_id","shelf_life","usual_storage"]
dff = dff.drop(items,axis=1)

# %%
dff
# Out:
#              product
# 0          spaghetti
# 1              onion
# 2              sugar
# 3            mustard
# 4       tomato sauce
# ..               ...
# 205  cooked broccoli
# 206         mushroom
# 207  cooked mushroom
# 208  sliced mushroom
# 209   dried mushroom
#
# [210 rows x 1 columns]

# %%
data = [i[0] for i in dff.values.tolist()]
data
# Out:
# ['spaghetti',
#  'onion',
#  'sugar',
#  'mustard',
#  'tomato sauce',
#  'flour',
#  'soy sauce',
#  'peanut',
#  'canned tuna',
#  'peeled tomato',
#  'dark chocolate',
#  'pappardelle pasta',
#  'pasta',
#  'soybean paste',
#  'penne pasta',
#  'red wine vinegar',
#  'apricot jam',
#  'bread slice',
#  'chocolate chips',
#  'honey',
#  'walnut',
#  'pistachio',
#  'self rising flour',
#  'pecan nuts',
#  'lemon curd',
#  'dried figs',
#  'cashew',
#  'dried cranberries',
#  'almond',
#  'dried apricot',
#  'tea',
#  'red lentils',
#  'risotto rice',
#  'wholemeal flour',
#  'fruit granola',
#  'canned salmon',
#  'pita bread',
#  'chocolate breakfast cereal',
#  'tuna fillets in olive',
#  'peanut butter',
#  'linguine pasta',
#  'sticky rice',
#  'macaroni pasta',
#  'lemon tuna fillet',
#  'barbecue sauce',
#  'humus',
#  'ginger biscuits',
#  'basmati rice',
#  'rapseed oil',
#  'mixed seeds',
#  'tortilla wraps',
#  'mixed nuts',
#  'instant coffee',
#  'oat biscuits',
# ...

# %%
df = pd.DataFrame()

#data = []

for i in data:
    url = "https://nutrition-by-api-ninjas.p.rapidapi.com/v1/nutrition"

    querystring = {"query":i}

    headers = {
        "X-RapidAPI-Key": "4e6b4ee722msh8985d3932acff73p173cadjsnb1362d9239ab",
        "X-RapidAPI-Host": "nutrition-by-api-ninjas.p.rapidapi.com"
    }
    
    response = requests.request("GET", url, headers=headers, params=querystring)

    data = response.json()

        # Convert the JSON data to a pandas dataframe
    #df = pd.DataFrame(data)

    df = df.append(data)

# %%
df.to_excel("product.xlsx")

# %%
import requests

url = "https://yummly2.p.rapidapi.com/categories/list"

headers = {
	"X-RapidAPI-Key": "4e6b4ee722msh8985d3932acff73p173cadjsnb1362d9239ab",
	"X-RapidAPI-Host": "yummly2.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)

# %%
data = data[:140]
data

# %%
df1 = pd.DataFrame()

URL = 'https://api.spoonacular.com/food/ingredients/search'

API_KEY = "7cba1ab21a3642f59ffb5628528c8435"
#data = []

for i in data:
    querystring = {
    'query': i, # The search query
    'apiKey': API_KEY, # Your API key Spooncular

}
    response = requests.request("GET", URL, params=querystring)
    #print(response)
    data1 = response.json()

        # Convert the JSON data to a pandas dataframe
    df1 = pd.DataFrame([data1] )

    df1 = df1.append(data1,ignore_index=True)

# %%
df1.to_excel("product1.xlsx")

# %%
data

# %%
import requests

df2 = pd.DataFrame()

#data = []

for i in data:

	url = "https://edamam-food-and-grocery-database.p.rapidapi.com/parser"

	querystring = {"ingr":i}

	headers = {
		"X-RapidAPI-Key": "4e6b4ee722msh8985d3932acff73p173cadjsnb1362d9239ab",
		"X-RapidAPI-Host": "edamam-food-and-grocery-database.p.rapidapi.com"}

	response = requests.request("GET", url, headers=headers, params=querystring)

	data1 = response.json()

    # Convert the JSON data to a pandas dataframe
	df2 = df2.append(data1,ignore_index="True")
# Out:
# C:\Users\Aai\AppData\Local\Temp\ipykernel_18484\4063149502.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(data1,ignore_index="True")
# C:\Users\Aai\AppData\Local\Temp\ipykernel_18484\4063149502.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(data1,ignore_index="True")
# C:\Users\Aai\AppData\Local\Temp\ipykernel_18484\4063149502.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(data1,ignore_index="True")
# C:\Users\Aai\AppData\Local\Temp\ipykernel_18484\4063149502.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(data1,ignore_index="True")
# ...

# %%
df2
# Out:
#                 text                                             parsed  \
# 0          spaghetti  [{'food': {'foodId': 'food_a8hs60uayl5icia1qe8...
# 1              onion  [{'food': {'foodId': 'food_bmrvi4ob4binw9a5m7l...
# 2              sugar  [{'food': {'foodId': 'food_axi2ijobrk819yb0adc...
# 3            mustard  [{'food': {'foodId': 'food_a34cdj5b0kyuhfbov30...
# 4       tomato sauce  [{'food': {'foodId': 'food_a6k79rrahp8fe2b26zu...
# ..               ...                                                ...
# 205  cooked broccoli  [{'food': {'foodId': 'food_aahw0jha9f8337ajbop...
# 206         mushroom  [{'food': {'foodId': 'food_bvlose6arfl26ra396s...
# 207  cooked mushroom  [{'food': {'foodId': 'food_bvlose6arfl26ra396s...
# 208  sliced mushroom  [{'food': {'foodId': 'food_bvlose6arfl26ra396s...
# 209   dried mushroom  [{'food': {'foodId': 'food_aws03zlajqq28lbdbg3...
#
#                                                  hints  \
# ...

# %%
import requests

df3 = pd.DataFrame()

#data = []

for i in data:

        url = "https://themealdb.p.rapidapi.com/search.php"

        querystring = {"s":i}

        headers = {
        "X-RapidAPI-Key": "4e6b4ee722msh8985d3932acff73p173cadjsnb1362d9239ab",
        "X-RapidAPI-Host": "themealdb.p.rapidapi.com"}

        response = requests.request("GET", url, headers=headers, params=querystring)

        data3 = response.json()

        # Convert the JSON data to a pandas dataframe
        df3 = df3.append(data3,ignore_index="True")
# Out:
# C:\Users\Aai\AppData\Local\Temp\ipykernel_18484\113482393.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append(data3,ignore_index="True")
# C:\Users\Aai\AppData\Local\Temp\ipykernel_18484\113482393.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append(data3,ignore_index="True")
# C:\Users\Aai\AppData\Local\Temp\ipykernel_18484\113482393.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append(data3,ignore_index="True")
# C:\Users\Aai\AppData\Local\Temp\ipykernel_18484\113482393.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append(data3,ignore_index="True")
# ...

# %%
df3.to_excel("pp.xlsx")

# %%
url = "https://themealdb.p.rapidapi.com/search.php"

querystring = {"c":"spaghetti"}

headers = {
	"X-RapidAPI-Key": "4e6b4ee722msh8985d3932acff73p173cadjsnb1362d9239ab",
	"X-RapidAPI-Host": "themealdb.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
print(response)
data5 = response.json()
print(data5)
# Out:
# <Response [200]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\Aai\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# c:\Users\Aai\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# c:\Users\Aai\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# c:\Users\Aai\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
# ...

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/food/ingredients/search"

querystring = {"query":"yogurt","addChildren":"true","minProteinPercent":"5","maxProteinPercent":"50","minFatPercent":"1","maxFatPercent":"10","minCarbsPercent":"5","maxCarbsPercent":"30","metaInformation":"false","intolerances":"egg","sort":"calories","sortDirection":"asc","offset":"0","number":"10"}

headers = {
	"X-RapidAPI-Key": "4e6b4ee722msh8985d3932acff73p173cadjsnb1362d9239ab",
	"X-RapidAPI-Host": "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}
