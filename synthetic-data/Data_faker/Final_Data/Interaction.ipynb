# %%
import uuid
import pandas as pd
import random
import requests

# %%
data = pd.read_excel("D:/UoE_Notes/Assignment/Group_Project/pratices/product_output.xlsx")
data
# Out:
#      customer_id  customer_name  product_id        purchase_date_time  \
# 0              3  Anne Hathaway          82  2022-04-04T06:52:30.000Z
# 1              1         Sam BF          48  2022-12-27T09:41:59.000Z
# 2              2   Alan Fleming          80  2022-07-05T04:02:36.000Z
# 3              3  Anne Hathaway          39  2022-11-03T07:19:59.000Z
# 4              4         Sam BF          71  2022-09-29T11:45:10.000Z
# ..           ...            ...         ...                       ...
# 395            0         Sam BF          62  2022-12-27T09:41:59.000Z
# 396            3  Anne Hathaway         135  2022-07-08T12:03:42.000Z
# 397            4         Sam BF          47  2022-04-04T06:52:30.000Z
# 398            0   Kate Sanders          52  2022-04-04T06:52:30.000Z
# 399            4   Alan Fleming          45  2022-03-12T03:25:20.000Z
#
#      invoice_id
# 0            23
# 1            20
# 2            16
# 3            30
# 4            20
# ..          ...
# ...

# %%
df = data.copy()

# %%
df

# %%
items = ["customer_name","purchase_date_time","invoice_id"]
df = df.drop(items,axis=1)

# %%
df

# %%
Allergies = ["Peanuts","No Allergies","Tree nuts(almonds, walnuts, pecans, and cashews)","Milk","Eggs","Fish","Shellfish ( crab, lobster, and shrimp)","Soy","Wheat","Sesame","Gluten","Corn","Mustard","Lupin","Sunflower seeds","Yeast"]
Categories = ["Gluten Free","Ketogenic","Vegetarian","Lacto-Vegetarian","Ovo-Vegetarian","Vegan","Pescetarian","Paleo","Primal","Low FODMAP","Whole30"]
df2 = pd.DataFrame([{"Categories":random.choice(Categories),"Allergies":random.choice(Allergies),"Weekly_Budget":random.randint(50, 150)} for i in range(201)])

# %%
df2
# Out:
#       Categories                                         Allergies  \
# 0        Whole30                                              Milk
# 1     Low FODMAP                                              Eggs
# 2      Ketogenic                                               Soy
# 3    Gluten Free                                              Fish
# 4     Vegetarian                                              Fish
# ..           ...                                               ...
# 196    Ketogenic  Tree nuts(almonds, walnuts, pecans, and cashews)
# 197    Ketogenic                                   Sunflower seeds
# 198        Vegan                                             Wheat
# 199        Vegan                                              Milk
# 200    Ketogenic                                      No Allergies
#
#      Weekly_Budget
# 0              123
# 1              144
# 2              140
# 3              135
# 4               92
# ..             ...
# ...

# %%
df2.to_excel("cate.xlsx")
